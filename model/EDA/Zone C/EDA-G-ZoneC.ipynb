# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "/content/drive/MyDrive/Data Mining Project/data/unclean data/FD_INDREGZC_2016.csv"

# Read the CSV file into a Pandas DataFrame
datazone = pd.read_csv(csv_file_path, delimiter=";")

datazone
# Out:
# <ipython-input-2-63cf7f1b652c>:7: DtypeWarning: Columns (1,2,3,4,11,12,13,15,18,21,24,39,40,48,49,54,55,56,70,71,77,80,83,84,89,91,92,93,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   datazone = pd.read_csv(csv_file_path, delimiter=";")
#          REGION NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  ANAI  \
# 0            44     1     3  2008     9    58      64      57       55  1959
# 1            44     1     3  2008     9    69      79      68       65  1948
# 2            44     2     4  1977     6    70      79      69       65  1948
# 3            44     3     3  2012     9    30      29      29       25  1985
# 4            44     3     3  2012     9    30      29      29       25  1985
# ...         ...   ...   ...   ...   ...   ...     ...     ...      ...   ...
# 3341342      53     Z     Z  ZZZZ     Z    85      80      84       80  1929
# 3341343      53     Z     Z  ZZZZ     Z    92      80      91       90  1922
# 3341344      53     Z     Z  ZZZZ     Z    70      79      69       65  1944
# 3341345      53     Z     Z  ZZZZ     Z    84      80      83       80  1930
# 3341346      53     Z     Z  ZZZZ     Z    68      79      67       65  1950
#
#          ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 0        ...  Z     Z    3     2    2   500    44  1    1   Z
# 1        ...  Z     Z    3     2    2   500    44  1    1   Z
# 2        ...  Z     Z    1     Z    1    22    12  0    1   Z
# 3        ...  1     4    3     2    2   300    41  0    1   Z
# 4        ...  1     4    3     2    2   300    41  0    1   Z
# ...      ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 3341342  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  0    Z   X
# 3341343  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  0    Z   X
# 3341344  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  0    Z   X
# 3341345  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  0    Z   X
# 3341346  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  0    Z   X
#
# [3341347 rows x 97 columns]

# %%
n_rows = 3000000

# %%
datazone = datazone.sample(n=n_rows, random_state=42)

datazone
# Out:
#          REGION   NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  \
# 3166663      53  329768     4  2001     9    55      54      54       50
# 3048598      53  273008     7  2014     9    25      24      24       20
# 2460934      52       Z     Z  ZZZZ     Z    79      79      78       75
# 1019595      44  475018     3  2017     9    30      29      29       25
# 1205384      44  561533     2  2010     9    40      39      39       35
# ...         ...     ...   ...   ...   ...   ...     ...     ...      ...
# 1070969      44  498970     2  2013     9    29      29      28       25
# 1755493      52  131812     4  1974     6    67      79      66       65
# 1353798      44  630682     5  2016     9    40      54      40       40
# 1311816      44  611200     3  1992     8    67      79      66       65
# 538264       44  250749     5  2001     9    46      54      45       45
#
#          ANAI  ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 3166663  1960  ...  1     4    2     2    1   303    41  1    2   Z
# 3048598  1991  ...  Z     Z    3     Z    2    12    11  1    1   Z
# 2460934  1935  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 1019595  1988  ...  1     4    1     2    1   300    41  1    2   Z
# 1205384  1978  ...  1     4    1     2    1   302    41  1    2   Z
# ...       ...  ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 1070969  1985  ...  1     4    3     2    2   300    41  1    2   Z
# 1755493  1947  ...  Z     Z    2     2    1   500    44  1    1   Z
# 1353798  1978  ...  1     4    3     1    2   201    32  1    1   Z
# 1311816  1947  ...  Z     Z    2     Z    1    22    12  1    1   Z
# 538264   1971  ...  1     4    1     2    1   302    41  0    2   Z
#
# [3000000 rows x 97 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Plot frequencies for each column
for col in columns_to_keep:
    plt.figure(figsize=(8, 6))

    # Convert all values to int except the excluded ones
    df[col] = df[col].apply(lambda x: int(x) if x not in exclude_values else x)

    value_counts = df[col].value_counts()

    # Print values corresponding to their frequencies
    for value, frequency in value_counts.items():
        print(f"{col}: {value} -> Frequency: {frequency}")

    value_counts.plot(kind='bar', title=f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# STAT_CONJ: B -> Frequency: 1944565
# STAT_CONJ: A -> Frequency: 1055435
# APAF: 3 -> Frequency: 796168
# APAF: 2 -> Frequency: 787456
# APAF: 1 -> Frequency: 713208
# APAF: 0 -> Frequency: 626780
# APAF: Z -> Frequency: 67634
# APAF: 6 -> Frequency: 3330
# APAF: 5 -> Frequency: 3257
# APAF: 4 -> Frequency: 2167
# LPRM: 1 -> Frequency: 1378920
# LPRM: 3 -> Frequency: 782259
# LPRM: 2 -> Frequency: 692121
# LPRM: Z -> Frequency: 67634
# LPRM: 6 -> Frequency: 30448
# LPRM: 5 -> Frequency: 22610
# LPRM: 7 -> Frequency: 12811
# LPRM: 8 -> Frequency: 10278
# LPRM: 4 -> Frequency: 2863
# LPRM: 9 -> Frequency: 56
# INFAM: 1 -> Frequency: 2303299
# INFAM: 0 -> Frequency: 609756
# INFAM: Z -> Frequency: 67634
# INFAM: 2 -> Frequency: 19311
# COUPLE: 2 -> Frequency: 1571790
# COUPLE: 1 -> Frequency: 1428210
# NPERR: 2 -> Frequency: 886622
# NPERR: 4 -> Frequency: 594216
# NPERR: 1 -> Frequency: 541593
# NPERR: 3 -> Frequency: 517226
# NPERR: 5 -> Frequency: 274824
# NPERR: 6 -> Frequency: 117885
# NPERR: Z -> Frequency: 67634
# NAT49: 997 -> Frequency: 2747088
# NAT49: 998 -> Frequency: 97110
# NAT49: 792 -> Frequency: 15674
# NAT49: 12 -> Frequency: 14601
# NAT49: 504 -> Frequency: 14184
# NAT49: 620 -> Frequency: 11458
# NAT49: AOC -> Frequency: 8928
# NAT49: 380 -> Frequency: 8788
# NAT49: 276 -> Frequency: 8246
# NAT49: AFR -> Frequency: 6321
# NAT49: 642 -> Frequency: 4707
# NAT49: 688 -> Frequency: 4529
# NAT49: 826 -> Frequency: 4526
# NAT49: 643 -> Frequency: 4347
# NAT49: EUR -> Frequency: 4043
# NAT49: HUE -> Frequency: 4042
# NAT49: 724 -> Frequency: 3996
# NAT49: 788 -> Frequency: 3828
# NAT49: 56 -> Frequency: 3596
# NAT49: 156 -> Frequency: 2656
# NAT49: 178 -> Frequency: 2329
# NAT49: 324 -> Frequency: 2264
# NAT49: 120 -> Frequency: 2164
# NAT49: 686 -> Frequency: 1883
# NAT49: 180 -> Frequency: 1842
# NAT49: 384 -> Frequency: 1553
# NAT49: 616 -> Frequency: 1523
# NAT49: AME -> Frequency: 1215
# NAT49: 756 -> Frequency: 1195
# NAT49: 174 -> Frequency: 1016
# NAT49: 704 -> Frequency: 988
# NAT49: 528 -> Frequency: 931
# NAT49: 450 -> Frequency: 889
# NAT49: 24 -> Frequency: 875
# NAT49: 76 -> Frequency: 791
# NAT49: 466 -> Frequency: 739
# NAT49: 840 -> Frequency: 695
# NAT49: 116 -> Frequency: 456
# NAT49: 332 -> Frequency: 455
# NAT49: 422 -> Frequency: 422
# NAT49: 392 -> Frequency: 415
# NAT49: 356 -> Frequency: 395
# NAT49: 144 -> Frequency: 394
# NAT49: 124 -> Frequency: 384
# NAT49: 480 -> Frequency: 348
# NAT49: 478 -> Frequency: 332
# NAT49: 170 -> Frequency: 325
# NAT49: 586 -> Frequency: 294
# NAT49: CAR -> Frequency: 220
# NATN12: 1 -> Frequency: 2747088
# NATN12: ZZ -> Frequency: 155802
# NATN12: 8 -> Frequency: 13454
# NATN12: 12 -> Frequency: 13318
# NATN12: 10 -> Frequency: 13139
# NATN12: 7 -> Frequency: 11701
# NATN12: 5 -> Frequency: 11141
# NATN12: 11 -> Frequency: 8903
# NATN12: 3 -> Frequency: 8584
# NATN12: 6 -> Frequency: 6249
# NATN12: 2 -> Frequency: 5440
# NATN12: 9 -> Frequency: 2633
# NATN12: 4 -> Frequency: 2548
# IMMI: 2 -> Frequency: 2785965
# IMMI: 1 -> Frequency: 214035
# INAT: 11 -> Frequency: 2747088
# INAT: 21 -> Frequency: 155802
# INAT: 12 -> Frequency: 97110
# DIPL_15: A -> Frequency: 762415
# DIPL_15: D -> Frequency: 658649
# DIPL_15: B -> Frequency: 615384
# DIPL_15: Z -> Frequency: 503328
# DIPL_15: C -> Frequency: 460224
# STAT: ZZ -> Frequency: 1796883
# STAT: 10 -> Frequency: 1073327
# STAT: 21 -> Frequency: 73103
# STAT: 22 -> Frequency: 55396
# STAT: 23 -> Frequency: 1291

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Change the type of unique values to int except "Z" and "ZZ"
for col in columns_to_keep:
    unique_values = df[col].unique()
    for value in unique_values:
        if value not in ["Z", "ZZ", "A", "B", "C", "D","AFR","AOC", "CAR", "EUR", "HUE","AME" ]:
            df[col] = df[col].replace(value, int(value))

# Calculate the number of rows and columns for subplots
num_columns = 3
num_rows = len(columns_to_keep) // num_columns + (len(columns_to_keep) % num_columns > 0)

# Create subplots
fig, axs = plt.subplots(num_rows, num_columns, figsize=(30, 20))

# Flatten the 2D axs array for easy iteration
axs = axs.flatten()

# Plot frequencies for each column
for i, col in enumerate(columns_to_keep):
    df[col].value_counts().plot(kind='bar', ax=axs[i])
    axs[i].set_title(f'Frequency of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

# Remove any empty subplots if there are fewer columns than rows * columns
for i in range(len(columns_to_keep), num_rows * num_columns):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()
