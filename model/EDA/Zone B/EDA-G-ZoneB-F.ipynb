# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "/content/drive/MyDrive/Data Mining Project/data/unclean data/FD_INDREGZB_2016.csv"

# Read the CSV file into a Pandas DataFrame
datazone = pd.read_csv(csv_file_path, delimiter=";")

datazone
# Out:
# <ipython-input-2-1495a62c7660>:7: DtypeWarning: Columns (1,2,3,4,11,12,13,15,18,21,24,39,40,48,49,54,55,56,70,71,77,80,83,84,89,91,92,93,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   datazone = pd.read_csv(csv_file_path, delimiter=";")
#          REGION NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  ANAI  \
# 0            24     1     5  2009     9    18      17      17       15  1998
# 1            24     1     5  2009     9    61      64      60       60  1955
# 2            24     2     5  2007     9    66      79      65       65  1949
# 3            24     2     5  2007     9    67      79      66       65  1948
# 4            24     3     4  2004     9    16      17      15       15  1998
# ...         ...   ...   ...   ...   ...   ...     ...     ...      ...   ...
# 3898448      32     Z     Z  ZZZZ     Z    21      24      20       20  1995
# 3898449      32     Z     Z  ZZZZ     Z    20      19      19       15  1996
# 3898450      32     Z     Z  ZZZZ     Z    19      19      18       15  1997
# 3898451      32     Z     Z  ZZZZ     Z    19      19      18       15  1997
# 3898452      32     Z     Z  ZZZZ     Z    19      19      18       15  1997
#
#          ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 0        ...  Z     Z    3     Z    2    30    20  1    1   Z
# 1        ...  1     4    3     Z    2    30    20  1    1   Z
# 2        ...  Z     Z    2     2    1   500    44  1    3   Z
# 3        ...  Z     Z    2     2    1   500    44  1    3   Z
# 4        ...  Z     Z    3     2    2   413    43  1    1   Z
# ...      ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 3898448  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3898449  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3898450  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3898451  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3898452  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
#
# [3898453 rows x 97 columns]

# %%
n_rows = 3000000

# %%
datazone = datazone.sample(n=n_rows, random_state=42)

datazone
# Out:
#          REGION   NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  \
# 1140885      27  221076     3  1967     5    82      80      81       80
# 3339736      32  480165     2  1989     7    52      54      51       50
# 3604266      32  596510     3  2009     9    37      39      36       35
# 1890572      28  236297     3  2016     9     9      10       8        5
# 3013430      32  336500     5  2009     9    46      54      45       45
# ...         ...     ...   ...   ...   ...   ...     ...     ...      ...
# 2104285      28  336043     1  1974     6    73      79      72       70
# 271850       24  127966     1  2018     9    33      39      32       30
# 1299798      27  297763     1  1977     6    66      79      65       65
# 390130       24  183517     1  1985     7    53      54      52       50
# 3458117      32  532268     3  2015     9    39      39      38       35
#
#          ANAI  ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 1140885  1934  ...  Z     Z    1     2    1   500    44  1    0   Z
# 3339736  1966  ...  Z     Z    1     2    1   400    42  1    1   Z
# 3604266  1980  ...  1     4    3     2    2   400    42  1    1   Z
# 1890572  2009  ...  Z     Z    3     1    2   202    32  1    0   Z
# 3013430  1972  ...  1     4    2     1    1   201    32  1    1   Z
# ...       ...  ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 2104285  1945  ...  Z     Z    1     Z    1    12    11  1    1   Z
# 271850   1985  ...  1     4    3     Z    2    11    11  1    0   Z
# 1299798  1951  ...  Z     Z    1     2    1   500    44  0    1   Z
# 390130   1961  ...  1     4    2     2    1   411    43  0    2   Z
# 3458117  1977  ...  2     4    1     2    1   403    42  1    1   Z
#
# [3000000 rows x 97 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Plot frequencies for each column
for col in columns_to_keep:
    plt.figure(figsize=(8, 6))

    # Convert all values to int except the excluded ones
    df[col] = df[col].apply(lambda x: int(x) if x not in exclude_values else x)

    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    # Print values corresponding to their frequencies
    for value, frequency in filtered_value_counts.items():
        print(f"{col}: {value} -> Frequency: {frequency}")

    filtered_value_counts.plot(kind='bar', title=f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# STAT_CONJ: B -> Frequency: 1975344
# STAT_CONJ: A -> Frequency: 1024656
# APAF: 3 -> Frequency: 840952
# APAF: 2 -> Frequency: 788462
# APAF: 1 -> Frequency: 703221
# APAF: 0 -> Frequency: 596505
# APAF: Z -> Frequency: 59652
# APAF: 6 -> Frequency: 4546
# APAF: 5 -> Frequency: 4060
# APAF: 4 -> Frequency: 2602
# LPRM: 1 -> Frequency: 1348511
# LPRM: 3 -> Frequency: 823451
# LPRM: 2 -> Frequency: 680831
# LPRM: Z -> Frequency: 59652
# LPRM: 6 -> Frequency: 36742
# LPRM: 5 -> Frequency: 26731
# LPRM: 8 -> Frequency: 10180
# LPRM: 7 -> Frequency: 10037
# LPRM: 4 -> Frequency: 3793
# INFAM: 1 -> Frequency: 2339421
# INFAM: 0 -> Frequency: 576143
# INFAM: Z -> Frequency: 59652
# INFAM: 2 -> Frequency: 24784
# COUPLE: 2 -> Frequency: 1594816
# COUPLE: 1 -> Frequency: 1405184
# NPERR: 2 -> Frequency: 862170
# NPERR: 4 -> Frequency: 587605
# NPERR: 3 -> Frequency: 534559
# NPERR: 1 -> Frequency: 510480
# NPERR: 5 -> Frequency: 290641
# NPERR: 6 -> Frequency: 154893
# NPERR: Z -> Frequency: 59652
# NAT49: 997 -> Frequency: 2757830
# NAT49: 998 -> Frequency: 95626
# NAT49: 504 -> Frequency: 22301
# NAT49: 12 -> Frequency: 20717
# NAT49: 620 -> Frequency: 15918
# NAT49: 792 -> Frequency: 10155
# NAT49: AOC -> Frequency: 7044
# NAT49: AFR -> Frequency: 6489
# NAT49: 380 -> Frequency: 5047
# NAT49: 56 -> Frequency: 4489
# NAT49: 788 -> Frequency: 4087
# NAT49: 724 -> Frequency: 3783
# NAT49: 178 -> Frequency: 3503
# NAT49: 826 -> Frequency: 2896
# NAT49: 642 -> Frequency: 2876
# NAT49: 686 -> Frequency: 2837
# NAT49: 180 -> Frequency: 2829
# NAT49: 688 -> Frequency: 2525
# NAT49: 156 -> Frequency: 2516
# NAT49: 324 -> Frequency: 2182
# NAT49: 120 -> Frequency: 2093
# NAT49: EUR -> Frequency: 2011
# NAT49: HUE -> Frequency: 1959
# NAT49: 643 -> Frequency: 1914
# NAT49: 384 -> Frequency: 1799
# NAT49: 616 -> Frequency: 1410
# NAT49: 466 -> Frequency: 1288
# NAT49: 276 -> Frequency: 1226
# NAT49: 528 -> Frequency: 1107
# NATN12: 1 -> Frequency: 2757830
# NATN12: ZZ -> Frequency: 146544
# NATN12: 8 -> Frequency: 18220
# NATN12: 7 -> Frequency: 14700
# NATN12: 10 -> Frequency: 13717
# NATN12: 5 -> Frequency: 10403
# NATN12: 12 -> Frequency: 9852
# NATN12: 2 -> Frequency: 9141
# NATN12: 11 -> Frequency: 4944
# NATN12: 3 -> Frequency: 4900
# NATN12: 6 -> Frequency: 3941
# NATN12: 4 -> Frequency: 3078
# NATN12: 9 -> Frequency: 2730
# IMMI: 2 -> Frequency: 2797583
# IMMI: 1 -> Frequency: 202417
# INAT: 11 -> Frequency: 2757830
# INAT: 21 -> Frequency: 146544
# INAT: 12 -> Frequency: 95626
# DIPL_15: A -> Frequency: 863311
# DIPL_15: B -> Frequency: 598211
# DIPL_15: D -> Frequency: 577073
# DIPL_15: Z -> Frequency: 525287
# DIPL_15: C -> Frequency: 436118
# STAT: ZZ -> Frequency: 1849253
# STAT: 10 -> Frequency: 1040457
# STAT: 21 -> Frequency: 62554
# STAT: 22 -> Frequency: 46375
# STAT: 23 -> Frequency: 1361

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Change the type of unique values to int except excluded values
for col in columns_to_keep:
    unique_values = df[col].unique()
    for value in unique_values:
        if value not in exclude_values:
            df[col] = df[col].replace(value, int(value))

# Calculate the number of rows and columns for subplots
num_columns = 3
num_rows = len(columns_to_keep) // num_columns + (len(columns_to_keep) % num_columns > 0)

# Create subplots
fig, axs = plt.subplots(num_rows, num_columns, figsize=(30, 20))

# Flatten the 2D axs array for easy iteration
axs = axs.flatten()

# Plot frequencies for each column
for i, col in enumerate(columns_to_keep):
    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    filtered_value_counts.plot(kind='bar', ax=axs[i])
    axs[i].set_title(f'Frequency of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

# Remove any empty subplots if there are fewer columns than rows * columns
for i in range(len(columns_to_keep), num_rows * num_columns):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()
