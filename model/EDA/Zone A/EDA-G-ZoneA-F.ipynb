# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "/content/drive/MyDrive/Data Mining Project/data/unclean data/FD_INDREGZA_2016.csv"

# Read the CSV file into a Pandas DataFrame
datazone = pd.read_csv(csv_file_path, delimiter=";")

datazone
# Out:
# <ipython-input-2-0d9a7c7f496a>:7: DtypeWarning: Columns (1,2,3,4,11,12,13,15,18,21,24,39,40,48,49,54,55,56,70,71,77,80,83,84,89,91,92,93,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   datazone = pd.read_csv(csv_file_path, delimiter=";")
#          REGION NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  ANAI  \
# 0            11     1     6  2016     9    30      29      29       25  1988
# 1            11     1     6  2016     9    21      24      20       20  1997
# 2            11     2     3  2013     9    41      54      40       40  1973
# 3            11     2     3  2013     9    30      29      29       25  1984
# 4            11     2     3  2013     9     9      10       8        5  2005
# ...         ...   ...   ...   ...   ...   ...     ...     ...      ...   ...
# 4315652      11     Z     Z  ZZZZ     Z    24      24      23       20  1994
# 4315653      11     Z     Z  ZZZZ     Z    12      14      12       10  2004
# 4315654      11     Z     Z  ZZZZ     Z    16      17      16       15  2000
# 4315655      11     Z     Z  ZZZZ     Z    35      39      34       30  1981
# 4315656      11     Z     Z  ZZZZ     Z    39      39      38       35  1977
#
#          ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 0        ...  Z     Z    3     Z    2    30    20  1    0   Z
# 1        ...  Z     Z    3     Z    2    30    20  1    0   Z
# 2        ...  1     4    1     2    1   402    42  1    2   Z
# 3        ...  Z     Z    1     2    1   402    42  1    2   Z
# 4        ...  Z     Z    1     2    1   402    42  1    2   Z
# ...      ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 4315652  ...  1     4    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 4315653  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 4315654  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 4315655  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 4315656  ...  2     5    Z     Z    Z   ZZZ    ZZ  1    Z   X
#
# [4315657 rows x 97 columns]

# %%
n_rows = 3000000

# %%
datazone = datazone.sample(n=n_rows, random_state=42)

datazone
# Out:
#          REGION    NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  \
# 3156800      11  1390786     1  1989     7    70      79      69       65
# 1602510      11   705999     4  2015     9     7      10       6        5
# 1044021      11   460062     3  1987     7    47      54      46       45
# 3099663      11  1365637     4  1996     8    61      64      60       60
# 349136       11   153634     6  2015     9    25      24      24       20
# ...         ...      ...   ...   ...   ...   ...     ...     ...      ...
# 3243123      11  1428842     4  2008     9    54      54      53       50
# 3717837      11  1637780     7  2016     9    10      10       9        5
# 3844968      11  1693805     4  2007     9     7      10       7        5
# 2290374      11  1008722     6  2013     9    28      29      27       25
# 1920510      11   845970     4  2013     9    71      79      70       70
#
#          ANAI  ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 3156800  1944  ...  Z     Z    3     Z    2    12    11  1    0   Z
# 1602510  2011  ...  Z     Z    3     2    2   301    41  1    1   Z
# 1044021  1970  ...  1     5    3     2    2   403    42  1    0   Z
# 3099663  1955  ...  Z     Z    3     2    2   410    43  1    1   Z
# 349136   1992  ...  Z     Z    3     2    2   400    42  1    0   Z
# ...       ...  ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 3243123  1964  ...  2     4    3     2    2   403    42  1    0   Z
# 3717837  2007  ...  Z     Z    3     2    2   302    41  1    2   Z
# 3844968  2009  ...  Z     Z    3     1    2   213    32  1    2   Z
# 2290374  1986  ...  1     5    3     2    2   300    41  1    1   Z
# 1920510  1947  ...  2     5    3     1    2   101    31  1    0   Z
#
# [3000000 rows x 97 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Plot frequencies for each column
for col in columns_to_keep:
    plt.figure(figsize=(8, 6))

    # Convert all values to int except the excluded ones
    df[col] = df[col].apply(lambda x: int(x) if x not in exclude_values else x)

    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    # Print values corresponding to their frequencies
    for value, frequency in filtered_value_counts.items():
        print(f"{col}: {value} -> Frequency: {frequency}")

    filtered_value_counts.plot(kind='bar', title=f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# STAT_CONJ: B -> Frequency: 2030986
# STAT_CONJ: A -> Frequency: 969014
# APAF: 3 -> Frequency: 922830
# APAF: 2 -> Frequency: 730058
# APAF: 1 -> Frequency: 639726
# APAF: 0 -> Frequency: 639468
# APAF: Z -> Frequency: 44779
# APAF: 6 -> Frequency: 9423
# APAF: 5 -> Frequency: 8295
# APAF: 4 -> Frequency: 5421
# LPRM: 1 -> Frequency: 1301287
# LPRM: 3 -> Frequency: 913051
# LPRM: 2 -> Frequency: 614403
# LPRM: 6 -> Frequency: 56974
# LPRM: Z -> Frequency: 44779
# LPRM: 5 -> Frequency: 31988
# LPRM: 7 -> Frequency: 16181
# LPRM: 8 -> Frequency: 14201
# LPRM: 4 -> Frequency: 6921
# INFAM: 1 -> Frequency: 2299558
# INFAM: 0 -> Frequency: 603346
# INFAM: 2 -> Frequency: 52317
# INFAM: Z -> Frequency: 44779
# COUPLE: 2 -> Frequency: 1705960
# COUPLE: 1 -> Frequency: 1294040
# NPERR: 2 -> Frequency: 702778
# NPERR: 4 -> Frequency: 636232
# NPERR: 3 -> Frequency: 553970
# NPERR: 1 -> Frequency: 505128
# NPERR: 5 -> Frequency: 340715
# NPERR: 6 -> Frequency: 216398
# NPERR: Z -> Frequency: 44779
# NAT49: 997 -> Frequency: 2260391
# NAT49: 998 -> Frequency: 290058
# NAT49: 12 -> Frequency: 55393
# NAT49: 620 -> Frequency: 53535
# NAT49: 504 -> Frequency: 39522
# NAT49: 788 -> Frequency: 20704
# NAT49: 156 -> Frequency: 20463
# NAT49: AFR -> Frequency: 18677
# NAT49: 466 -> Frequency: 18003
# NAT49: AOC -> Frequency: 16634
# NAT49: 792 -> Frequency: 15191
# NAT49: 642 -> Frequency: 13609
# NAT49: 384 -> Frequency: 12581
# NAT49: 380 -> Frequency: 12216
# NAT49: 686 -> Frequency: 10353
# NAT49: 178 -> Frequency: 10119
# NAT49: 144 -> Frequency: 9772
# NAT49: 724 -> Frequency: 9650
# NAT49: 180 -> Frequency: 9304
# NAT49: 120 -> Frequency: 8680
# NAT49: 332 -> Frequency: 7060
# NAT49: EUR -> Frequency: 7052
# NAT49: 616 -> Frequency: 6861
# NAT49: HUE -> Frequency: 5917
# NAT49: 826 -> Frequency: 4343
# NAT49: 324 -> Frequency: 4188
# NAT49: 276 -> Frequency: 4165
# NAT49: AME -> Frequency: 4100
# NAT49: 586 -> Frequency: 4067
# NAT49: 356 -> Frequency: 4063
# NAT49: 688 -> Frequency: 4058
# NAT49: 840 -> Frequency: 3746
# NAT49: 643 -> Frequency: 3388
# NAT49: 56 -> Frequency: 3318
# NAT49: 392 -> Frequency: 3067
# NAT49: 76 -> Frequency: 2788
# NAT49: 174 -> Frequency: 2625
# NAT49: 478 -> Frequency: 2440
# NAT49: 450 -> Frequency: 2346
# NAT49: 704 -> Frequency: 2255
# NAT49: 170 -> Frequency: 2108
# NAT49: 480 -> Frequency: 2047
# NAT49: 116 -> Frequency: 1919
# NAT49: 24 -> Frequency: 1818
# NAT49: 422 -> Frequency: 1538
# NAT49: 528 -> Frequency: 1339
# NAT49: 124 -> Frequency: 1162
# NATN12: 1 -> Frequency: 2260391
# NATN12: ZZ -> Frequency: 449551
# NATN12: 10 -> Frequency: 63510
# NATN12: 12 -> Frequency: 60830
# NATN12: 7 -> Frequency: 41645
# NATN12: 8 -> Frequency: 37440
# NATN12: 2 -> Frequency: 21654
# NATN12: 9 -> Frequency: 18345
# NATN12: 5 -> Frequency: 16469
# NATN12: 6 -> Frequency: 9254
# NATN12: 11 -> Frequency: 8128
# NATN12: 3 -> Frequency: 6718
# NATN12: 4 -> Frequency: 6065
# IMMI: 2 -> Frequency: 2384493
# IMMI: 1 -> Frequency: 615507
# INAT: 11 -> Frequency: 2260391
# INAT: 21 -> Frequency: 449551
# INAT: 12 -> Frequency: 290058
# DIPL_15: D -> Frequency: 973479
# DIPL_15: A -> Frequency: 676724
# DIPL_15: Z -> Frequency: 565679
# DIPL_15: C -> Frequency: 433464
# DIPL_15: B -> Frequency: 350654
# STAT: ZZ -> Frequency: 1658159
# STAT: 10 -> Frequency: 1212892
# STAT: 21 -> Frequency: 79422
# STAT: 22 -> Frequency: 48475
# STAT: 23 -> Frequency: 1052

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Change the type of unique values to int except excluded values
for col in columns_to_keep:
    unique_values = df[col].unique()
    for value in unique_values:
        if value not in exclude_values:
            df[col] = df[col].replace(value, int(value))

# Calculate the number of rows and columns for subplots
num_columns = 3
num_rows = len(columns_to_keep) // num_columns + (len(columns_to_keep) % num_columns > 0)

# Create subplots
fig, axs = plt.subplots(num_rows, num_columns, figsize=(30, 20))

# Flatten the 2D axs array for easy iteration
axs = axs.flatten()

# Plot frequencies for each column
for i, col in enumerate(columns_to_keep):
    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    filtered_value_counts.plot(kind='bar', ax=axs[i])
    axs[i].set_title(f'Frequency of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

# Remove any empty subplots if there are fewer columns than rows * columns
for i in range(len(columns_to_keep), num_rows * num_columns):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()
