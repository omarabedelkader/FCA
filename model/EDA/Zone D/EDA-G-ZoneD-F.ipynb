# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = "/content/drive/MyDrive/Data Mining Project/data/unclean data/FD_INDREGZD_2016.csv"

# Read the CSV file into a Pandas DataFrame
datazone = pd.read_csv(csv_file_path, delimiter=";")

datazone
# Out:
# <ipython-input-8-529c466d7b87>:7: DtypeWarning: Columns (1,2,3,4,11,12,13,15,18,21,24,39,40,48,49,54,55,56,70,71,77,80,83,84,89,91,92,93,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   datazone = pd.read_csv(csv_file_path, delimiter=";")
#          REGION NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  ANAI  \
# 0            75     1     5  2013     9    14      14      13       10  2001
# 1            75     1     5  2013     9    39      39      38       35  1976
# 2            75     2     5  1998     8    53      54      52       50  1963
# 3            75     2     5  1998     8    50      54      49       45  1966
# 4            75     2     5  1998     8    17      17      16       15  1999
# ...         ...   ...   ...   ...   ...   ...     ...     ...      ...   ...
# 3116438      76     Z     Z  ZZZZ     Z    29      29      28       25  1987
# 3116439      76     Z     Z  ZZZZ     Z    46      54      45       45  1970
# 3116440      76     Z     Z  ZZZZ     Z    49      54      48       45  1966
# 3116441      76     Z     Z  ZZZZ     Z    29      29      28       25  1986
# 3116442      76     Z     Z  ZZZZ     Z    50      54      49       45  1965
#
#          ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 0        ...  Z     Z    3     1    2   201    32  1    1   Z
# 1        ...  1     4    3     1    2   201    32  1    1   Z
# 2        ...  1     1    1     2    1   301    41  1    2   Z
# 3        ...  1     1    1     2    1   301    41  1    2   Z
# 4        ...  Z     Z    1     2    1   301    41  1    2   Z
# ...      ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 3116438  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3116439  ...  1     4    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3116440  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3116441  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
# 3116442  ...  Z     Z    Z     Z    Z   ZZZ    ZZ  1    Z   X
#
# [3116443 rows x 97 columns]

# %%
n_rows = 3000000

# %%
datazone = datazone.sample(n=n_rows, random_state=42)

datazone
# Out:
#          REGION   NUMMR ACHLR  AEMM AEMMR  AGED  AGER20  AGEREV  AGEREVQ  \
# 599835       75  293721     1  2015     9    19      19      18       15
# 251467       75  123085     3  2007     9    70      79      69       65
# 1851194      76  148625     3  1992     8    22      24      21       20
# 1964022      76  203062     6  2009     9    48      54      47       45
# 1753264      76  101416     3  1985     7    88      80      87       85
# ...         ...     ...   ...   ...   ...   ...     ...     ...      ...
# 2094916      76  266346     3  1993     8    68      79      67       65
# 786359       75  385238     5  2006     9    16      17      15       15
# 573791       75  280880     3  1987     7    64      64      63       60
# 818929       75  401154     3  1988     7    32      39      31       30
# 1373547      75  672508     5  2001     9    25      24      24       20
#
#          ANAI  ... TP TRANS TYPC TYPFC TYPL TYPMD TYPMR UR VOIT  WC
# 599835   1997  ...  Z     Z    3     Z    2    22    12  1    0   Z
# 251467   1947  ...  Z     Z    1     2    1   500    44  1    1   Z
# 1851194  1992  ...  Z     Z    3     Z    2    30    20  1    2   Z
# 1964022  1966  ...  1     4    1     2    1   400    42  1    1   Z
# 1753264  1930  ...  Z     Z    2     2    1   500    44  1    1   Z
# ...       ...  ... ..   ...  ...   ...  ...   ...   ... ..  ...  ..
# 2094916  1948  ...  Z     Z    3     2    2   500    44  1    1   Z
# 786359   1999  ...  Z     Z    1     Z    1    30    20  1    2   Z
# 573791   1953  ...  Z     Z    1     Z    1    22    12  1    1   Z
# 818929   1982  ...  1     4    1     2    1   301    41  1    2   Z
# 1373547  1992  ...  Z     Z    1     Z    1   301    41  1    2   Z
#
# [3000000 rows x 97 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Plot frequencies for each column
for col in columns_to_keep:
    plt.figure(figsize=(8, 6))

    # Convert all values to int except the excluded ones
    df[col] = df[col].apply(lambda x: int(x) if x not in exclude_values else x)

    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    # Print values corresponding to their frequencies
    for value, frequency in filtered_value_counts.items():
        print(f"{col}: {value} -> Frequency: {frequency}")

    filtered_value_counts.plot(kind='bar', title=f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# STAT_CONJ: B -> Frequency: 1985598
# STAT_CONJ: A -> Frequency: 1014402
# APAF: 2 -> Frequency: 787308
# APAF: 3 -> Frequency: 742029
# APAF: 1 -> Frequency: 703345
# APAF: 0 -> Frequency: 689690
# APAF: Z -> Frequency: 64416
# APAF: 5 -> Frequency: 4971
# APAF: 6 -> Frequency: 4773
# APAF: 4 -> Frequency: 3468
# LPRM: 1 -> Frequency: 1427217
# LPRM: 3 -> Frequency: 729290
# LPRM: 2 -> Frequency: 678995
# LPRM: Z -> Frequency: 64416
# LPRM: 6 -> Frequency: 38323
# LPRM: 5 -> Frequency: 29592
# LPRM: 7 -> Frequency: 15927
# LPRM: 8 -> Frequency: 12176
# LPRM: 4 -> Frequency: 3986
# INFAM: 1 -> Frequency: 2241909
# INFAM: 0 -> Frequency: 664637
# INFAM: Z -> Frequency: 64416
# INFAM: 2 -> Frequency: 29038
# COUPLE: 2 -> Frequency: 1589272
# COUPLE: 1 -> Frequency: 1410728
# NPERR: 2 -> Frequency: 938062
# NPERR: 1 -> Frequency: 578315
# NPERR: 4 -> Frequency: 552483
# NPERR: 3 -> Frequency: 546060
# NPERR: 5 -> Frequency: 218289
# NPERR: 6 -> Frequency: 102375
# NPERR: Z -> Frequency: 64416
# NAT49: 997 -> Frequency: 2698024
# NAT49: 998 -> Frequency: 117537
# NAT49: 504 -> Frequency: 31428
# NAT49: 620 -> Frequency: 23190
# NAT49: 12 -> Frequency: 16371
# NAT49: 724 -> Frequency: 16102
# NAT49: 826 -> Frequency: 13395
# NAT49: AOC -> Frequency: 6772
# NAT49: AFR -> Frequency: 5610
# NAT49: 56 -> Frequency: 5516
# NAT49: 792 -> Frequency: 5490
# NAT49: EUR -> Frequency: 5443
# NAT49: 380 -> Frequency: 5251
# NAT49: 642 -> Frequency: 5014
# NAT49: 788 -> Frequency: 4025
# NAT49: 276 -> Frequency: 3340
# NAT49: 528 -> Frequency: 2804
# NAT49: 156 -> Frequency: 2679
# NAT49: 643 -> Frequency: 2609
# NAT49: HUE -> Frequency: 2533
# NAT49: 686 -> Frequency: 2255
# NAT49: 324 -> Frequency: 2075
# NAT49: AME -> Frequency: 1907
# NAT49: 120 -> Frequency: 1740
# NAT49: 384 -> Frequency: 1673
# NAT49: 616 -> Frequency: 1576
# NAT49: 450 -> Frequency: 1377
# NAT49: 178 -> Frequency: 1373
# NAT49: 76 -> Frequency: 1202
# NAT49: 840 -> Frequency: 1106
# NAT49: 688 -> Frequency: 1062
# NAT49: 180 -> Frequency: 1056
# NATN12: 1 -> Frequency: 2698024
# NATN12: ZZ -> Frequency: 184439
# NATN12: 8 -> Frequency: 22076
# NATN12: 4 -> Frequency: 19201
# NATN12: 7 -> Frequency: 14721
# NATN12: 12 -> Frequency: 13198
# NATN12: 2 -> Frequency: 11829
# NATN12: 10 -> Frequency: 11769
# NATN12: 5 -> Frequency: 9035
# NATN12: 3 -> Frequency: 7664
# NATN12: 6 -> Frequency: 3466
# NATN12: 9 -> Frequency: 2527
# NATN12: 11 -> Frequency: 2051
# IMMI: 2 -> Frequency: 2741919
# IMMI: 1 -> Frequency: 258081
# INAT: 11 -> Frequency: 2698024
# INAT: 21 -> Frequency: 184439
# INAT: 12 -> Frequency: 117537
# DIPL_15: A -> Frequency: 763448
# DIPL_15: D -> Frequency: 715054
# DIPL_15: B -> Frequency: 566354
# DIPL_15: C -> Frequency: 487012
# DIPL_15: Z -> Frequency: 468132
# STAT: ZZ -> Frequency: 1831286
# STAT: 10 -> Frequency: 1004378
# STAT: 21 -> Frequency: 101264
# STAT: 22 -> Frequency: 61119
# STAT: 23 -> Frequency: 1953

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame from the list of documents
df = datazone

# Columns to keep for plotting frequencies
columns_to_keep = ['STAT_CONJ', 'APAF', 'LPRM', 'INFAM', 'COUPLE', 'NPERR', 'NAT49', 'NATN12', 'IMMI', 'INAT', 'DIPL_15', 'STAT']

# Values to exclude from conversion to int
exclude_values = ["Z", "ZZ", "A", "B", "C", "D", "AFR", "AOC", "CAR", "EUR", "HUE", "AME"]

# Minimum frequency threshold
min_frequency = 1000

# Change the type of unique values to int except excluded values
for col in columns_to_keep:
    unique_values = df[col].unique()
    for value in unique_values:
        if value not in exclude_values:
            df[col] = df[col].replace(value, int(value))

# Calculate the number of rows and columns for subplots
num_columns = 3
num_rows = len(columns_to_keep) // num_columns + (len(columns_to_keep) % num_columns > 0)

# Create subplots
fig, axs = plt.subplots(num_rows, num_columns, figsize=(30, 20))

# Flatten the 2D axs array for easy iteration
axs = axs.flatten()

# Plot frequencies for each column
for i, col in enumerate(columns_to_keep):
    value_counts = df[col].value_counts()

    # Filter values based on frequency
    filtered_value_counts = value_counts[value_counts >= min_frequency]

    filtered_value_counts.plot(kind='bar', ax=axs[i])
    axs[i].set_title(f'Frequency of {col}')
    axs[i].set_xlabel(col)
    axs[i].set_ylabel('Frequency')

# Remove any empty subplots if there are fewer columns than rows * columns
for i in range(len(columns_to_keep), num_rows * num_columns):
    fig.delaxes(axs[i])

plt.tight_layout()
plt.show()
